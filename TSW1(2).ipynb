# %%
import zipfile
import os

#dearhivare
uploaded_file_path = "ML_dataset.zip"
extraction_dir = "ML_dataset"

with zipfile.ZipFile(uploaded_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_dir)

print(f"Files extracted to: {extraction_dir}")
# Out:
# Files extracted to: ML_dataset

# %% [markdown]
# IMPLEMENATRE 1 - simple neural network for binary classification

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns


base_dir = "ML_dataset/ML_dataset"
directories = ['S', 'Z']
labels_map = {'S': 1, 'Z': 0}  #1 = epileptic 0 = healthy

X, y = [], [] #lists
max_length = 1000  #fixed length for all time series

for folder_name in directories:
    folder_path = os.path.join(base_dir, folder_name)   #to know in what subdirectory we are
    for file in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file)
        print(file_path)
        data = np.loadtxt(file_path)  #time series represented by the files
        X.append(data) #data from each file goes into input
        y.append(labels_map[folder_name]) #adds labels

X = pad_sequences(X, maxlen=max_length, padding='post', truncating='post') #all timeseries become 1000 numbers long
y = np.array(y) #for ML np.array more efficient than lists

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=60)

#simole feedforward nn
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(max_length,)),  #input layer
    tf.keras.layers.Dense(16, activation='relu'), #hidden layer (16 neurons)
    tf.keras.layers.Dense(1, activation='sigmoid') #output layer (1 neuron)
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")

predictions = model.predict(X_test)
predicted_labels = (predictions > 0.5).astype(int) #converts probabilities given by sigmoid function into 0 and 1; false=0 (healthy) and true=1 (epileptic)
conf_matrix = confusion_matrix(y_test, predicted_labels)
plt.figure(figsize=(6, 5))
print("Confusion Matrix:\n", conf_matrix)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Healthy (0)', 'Epileptic (1)'],
            yticklabels=['Healthy (0)', 'Epileptic (1)'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# ML_dataset/ML_dataset/S/S052.txt
# ML_dataset/ML_dataset/S/S005.txt
# ML_dataset/ML_dataset/S/S099.txt
# ML_dataset/ML_dataset/S/S098.txt
# ML_dataset/ML_dataset/S/S084.txt
# ML_dataset/ML_dataset/S/S004.txt
# ML_dataset/ML_dataset/S/S003.txt
# ML_dataset/ML_dataset/S/S033.txt
# ML_dataset/ML_dataset/S/S035.txt
# ML_dataset/ML_dataset/S/S092.txt
# ML_dataset/ML_dataset/S/S046.txt
# ML_dataset/ML_dataset/S/S032.txt
# ML_dataset/ML_dataset/S/S015.txt
# ML_dataset/ML_dataset/S/S070.txt
# ML_dataset/ML_dataset/S/S094.txt
# ML_dataset/ML_dataset/S/S080.txt
# ML_dataset/ML_dataset/S/S077.txt
# ML_dataset/ML_dataset/S/S097.txt
# ML_dataset/ML_dataset/S/S073.txt
# ML_dataset/ML_dataset/S/S057.txt
# ML_dataset/ML_dataset/S/S093.txt
# ML_dataset/ML_dataset/S/S002.txt
# ML_dataset/ML_dataset/S/S043.txt
# ML_dataset/ML_dataset/S/S022.txt
# ML_dataset/ML_dataset/S/S075.txt
# ML_dataset/ML_dataset/S/S037.txt
# ML_dataset/ML_dataset/S/S066.txt
# ML_dataset/ML_dataset/S/S053.txt
# ML_dataset/ML_dataset/S/S060.txt
# ML_dataset/ML_dataset/S/S029.txt
# ML_dataset/ML_dataset/S/S068.txt
# ML_dataset/ML_dataset/S/S088.txt
# ML_dataset/ML_dataset/S/S047.txt
# ML_dataset/ML_dataset/S/S006.txt
# ML_dataset/ML_dataset/S/S058.txt
# ML_dataset/ML_dataset/S/S008.txt
# ML_dataset/ML_dataset/S/S065.txt
# ML_dataset/ML_dataset/Z/Z069.txt
# ML_dataset/ML_dataset/Z/Z061.txt
# ML_dataset/ML_dataset/Z/Z083.txt
# ML_dataset/ML_dataset/Z/Z064.txt
# ML_dataset/ML_dataset/Z/Z041.txt
# ML_dataset/ML_dataset/Z/Z085.txt
# ML_dataset/ML_dataset/Z/Z018.txt
# ML_dataset/ML_dataset/Z/Z099.txt
# ML_dataset/ML_dataset/Z/Z052.txt
# ML_dataset/ML_dataset/Z/Z094.txt
# ML_dataset/ML_dataset/Z/Z093.txt
# ML_dataset/ML_dataset/Z/Z036.txt
# ML_dataset/ML_dataset/Z/Z050.txt
# ML_dataset/ML_dataset/Z/Z008.txt
# ML_dataset/ML_dataset/Z/Z012.txt
# ML_dataset/ML_dataset/Z/Z071.txt
# ML_dataset/ML_dataset/Z/Z072.txt
# ML_dataset/ML_dataset/Z/Z051.txt
# ML_dataset/ML_dataset/Z/Z088.txt
# ML_dataset/ML_dataset/Z/Z031.txt
# ML_dataset/ML_dataset/Z/Z068.txt
# ML_dataset/ML_dataset/Z/Z016.txt
# ML_dataset/ML_dataset/Z/Z095.txt
# ML_dataset/ML_dataset/Z/Z097.txt
# ML_dataset/ML_dataset/Z/Z078.txt
# ML_dataset/ML_dataset/Z/Z058.txt
# ML_dataset/ML_dataset/Z/Z026.txt
# ML_dataset/ML_dataset/Z/Z029.txt
# ML_dataset/ML_dataset/Z/Z057.txt
# ML_dataset/ML_dataset/Z/Z067.txt
# ML_dataset/ML_dataset/Z/Z045.txt
# ML_dataset/ML_dataset/Z/Z003.txt
# ML_dataset/ML_dataset/Z/Z024.txt
# ML_dataset/ML_dataset/Z/Z082.txt
# ML_dataset/ML_dataset/Z/Z042.txt
# ML_dataset/ML_dataset/Z/Z004.txt
# ML_dataset/ML_dataset/Z/Z040.txt
# ML_dataset/ML_dataset/Z/Z096.txt
# ML_dataset/ML_dataset/Z/Z014.txt
# ML_dataset/ML_dataset/Z/Z046.txt
# ML_dataset/ML_dataset/Z/Z062.txt
# ML_dataset/ML_dataset/Z/Z081.txt
# ML_dataset/ML_dataset/Z/Z100.txt
# ML_dataset/ML_dataset/Z/Z034.txt
# ML_dataset/ML_dataset/Z/Z011.txt
# ML_dataset/ML_dataset/Z/Z079.txt
# ML_dataset/ML_dataset/Z/Z098.txt
# ML_dataset/ML_dataset/Z/Z005.txt
# ML_dataset/ML_dataset/Z/Z063.txt
# ML_dataset/ML_dataset/Z/Z035.txt
# ML_dataset/ML_dataset/Z/Z080.txt
# ML_dataset/ML_dataset/Z/Z021.txt
# ML_dataset/ML_dataset/Z/Z066.txt
# ML_dataset/ML_dataset/Z/Z075.txt
# ML_dataset/ML_dataset/Z/Z090.txt
# ML_dataset/ML_dataset/Z/Z010.txt
# ML_dataset/ML_dataset/Z/Z049.txt
# ML_dataset/ML_dataset/Z/Z027.txt
# ML_dataset/ML_dataset/Z/Z020.txt
# ML_dataset/ML_dataset/Z/Z032.txt
# ML_dataset/ML_dataset/Z/Z013.txt
# ML_dataset/ML_dataset/Z/Z086.txt
# ML_dataset/ML_dataset/Z/Z048.txt
# ML_dataset/ML_dataset/Z/Z022.txt
# ML_dataset/ML_dataset/Z/Z056.txt
# ML_dataset/ML_dataset/Z/Z092.txt
# ML_dataset/ML_dataset/Z/Z053.txt
# ML_dataset/ML_dataset/Z/Z087.txt
# ML_dataset/ML_dataset/Z/Z089.txt
# ML_dataset/ML_dataset/Z/Z007.txt
# ML_dataset/ML_dataset/Z/Z070.txt
# ML_dataset/ML_dataset/Z/Z077.txt
# ML_dataset/ML_dataset/Z/Z055.txt
# ML_dataset/ML_dataset/Z/Z076.txt
# ML_dataset/ML_dataset/Z/Z025.txt
# ML_dataset/ML_dataset/Z/Z047.txt
# ML_dataset/ML_dataset/Z/Z001.txt
# ML_dataset/ML_dataset/Z/Z006.txt
# ML_dataset/ML_dataset/Z/Z019.txt
# ML_dataset/ML_dataset/Z/Z084.txt
# ML_dataset/ML_dataset/Z/Z073.txt
# ML_dataset/ML_dataset/Z/Z033.txt
# ML_dataset/ML_dataset/Z/Z015.txt
# ML_dataset/ML_dataset/Z/Z017.txt
# ML_dataset/ML_dataset/Z/Z059.txt
# ML_dataset/ML_dataset/Z/Z065.txt
# ML_dataset/ML_dataset/Z/Z074.txt
# ML_dataset/ML_dataset/Z/Z023.txt
# ML_dataset/ML_dataset/Z/Z028.txt
# ML_dataset/ML_dataset/Z/Z038.txt
# ML_dataset/ML_dataset/Z/Z091.txt
# ML_dataset/ML_dataset/Z/Z002.txt
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.5312 - loss: 122.2988 - val_accuracy: 0.5938 - val_loss: 117.2479
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6792 - loss: 40.4023 - val_accuracy: 0.5625 - val_loss: 89.1090
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8083 - loss: 19.1588 - val_accuracy: 0.6875 - val_loss: 75.3684
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8323 - loss: 6.5191 - val_accuracy: 0.6875 - val_loss: 66.4046
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8656 - loss: 4.0643 - val_accuracy: 0.6562 - val_loss: 59.3950
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9292 - loss: 1.5203 - val_accuracy: 0.6250 - val_loss: 54.6816
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9656 - loss: 0.8577 - val_accuracy: 0.6250 - val_loss: 51.9540
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9625 - loss: 0.6356 - val_accuracy: 0.6250 - val_loss: 50.1668
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9771 - loss: 0.0485 - val_accuracy: 0.6250 - val_loss: 49.3522
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 4.0210e-04 - val_accuracy: 0.5938 - val_loss: 48.7898
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9917 - loss: 0.0267 - val_accuracy: 0.5938 - val_loss: 47.8544
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 2.4024e-04 - val_accuracy: 0.5938 - val_loss: 47.0849
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.3685e-04 - val_accuracy: 0.5938 - val_loss: 46.6024
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 8.9938e-05 - val_accuracy: 0.5938 - val_loss: 46.2662
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.3674e-04 - val_accuracy: 0.5938 - val_loss: 46.0380
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 2.1088e-04 - val_accuracy: 0.5938 - val_loss: 45.8856
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.2610e-04 - val_accuracy: 0.5938 - val_loss: 45.7832
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 3.3784e-04 - val_accuracy: 0.5938 - val_loss: 45.7149
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 7.4866e-05 - val_accuracy: 0.5938 - val_loss: 45.6693
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 3.1560e-04 - val_accuracy: 0.5938 - val_loss: 45.6396
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.1718e-04 - val_accuracy: 0.5938 - val_loss: 45.6202
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 2.7691e-04 - val_accuracy: 0.5938 - val_loss: 45.6077
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 2.6345e-04 - val_accuracy: 0.5938 - val_loss: 45.6000
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 9.2142e-05 - val_accuracy: 0.5938 - val_loss: 45.5954
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 2.4169e-04 - val_accuracy: 0.5938 - val_loss: 45.5932
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.3396e-04 - val_accuracy: 0.5938 - val_loss: 45.5924
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.2921e-04 - val_accuracy: 0.5938 - val_loss: 45.5926
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss:
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 2.4399e-05 - val_accuracy: 0.5938 - val_loss: 45.6562
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.5332e-05 - val_accuracy: 0.5938 - val_loss: 45.6572
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 3.5168e-05 - val_accuracy: 0.5938 - val_loss: 45.6582
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 5.8034e-05 - val_accuracy: 0.5938 - val_loss: 45.6591
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 3.5337e-05 - val_accuracy: 0.5938 - val_loss: 45.6601
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 5.5890e-05 - val_accuracy: 0.5938 - val_loss: 45.6610
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 3.2675e-05 - val_accuracy: 0.5938 - val_loss: 45.6620
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.3398e-05 - val_accuracy: 0.5938 - val_loss: 45.6629
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 5.4258e-05 - val_accuracy: 0.5938 - val_loss: 45.6638
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.2986e-05 - val_accuracy: 0.5938 - val_loss: 45.6648
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.9411e-05 - val_accuracy: 0.5938 - val_loss: 45.6656
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 2.9695e-05 - val_accuracy: 0.5938 - val_loss: 45.6665
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.3681e-05 - val_accuracy: 0.5938 - val_loss: 45.6674
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.9097e-05 - val_accuracy: 0.5938 - val_loss: 45.6683
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.2597e-05 - val_accuracy: 0.5938 - val_loss: 45.6691
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.1099e-05 - val_accuracy: 0.5938 - val_loss: 45.6700
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 1.1867e-05 - val_accuracy: 0.5938 - val_loss: 45.6708
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.0220e-05 - val_accuracy: 0.5938 - val_loss: 45.6718
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.7405e-05 - val_accuracy: 0.5938 - val_loss: 45.6727
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.6190e-05 - val_accuracy: 0.5938 - val_loss: 45.6736
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 1.6445e-05 - val_accuracy: 0.5938 - val_loss: 45.6744
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 1.7829e-05 - val_accuracy: 0.5938 - val_loss: 45.6752
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.3969e-05 - val_accuracy: 0.5938 - val_loss: 45.6760
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.7452e-05 - val_accuracy: 0.5938 - val_loss: 45.6769
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 2.4673e-05 - val_accuracy: 0.5938 - val_loss: 45.6777
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 2.4008e-05 - val_accuracy: 0.5938 - val_loss: 45.6785
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 3.9826e-05 - val_accuracy: 0.5938 - val_loss: 45.6792
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7125 - loss: 37.2462
# Test Accuracy: 0.7250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confusion Matrix:
#  [[15  4]
#  [ 7 14]]

# %% [markdown]
# IMPLEMENTARE 2 - MLPclassifier for binary classification

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

total_conf_matrix = np.zeros((2, 2))

base_dir = "ML_dataset/ML_dataset"
directories = ['S', 'Z']
labels_map = {'S': 1, 'Z': 0}  # 1 = epileptic, 0 = healthy

X, y = [], []

for folder_name in directories:
    folder_path = os.path.join(base_dir, folder_name)
    for file in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file)
        #print(f"Loading: {file_path}")
        data = np.loadtxt(file_path)
        X.append(data)  #
        y.append(labels_map[folder_name])

X = np.array(X)
y = np.array(y)
repeats = 100
accuracies = []

for i in range(repeats):
    print(f"Iteration {i+1}/{repeats}")
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    scaler = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    mlp = MLPClassifier(hidden_layer_sizes=(16, 8, 1), solver='adam', activation='tanh', max_iter=10000)
    mlp.fit(X_train_scaled, y_train)
    y_pred = mlp.predict(X_test_scaled)
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)
    total_conf_matrix += confusion_matrix(y_test, y_pred)

print("Accuracies across 100 iterations:", accuracies)
print(f"Mean Accuracy: {np.mean(accuracies):.4f}")
print("Aggregated Confusion Matrix:\n", total_conf_matrix)

import matplotlib.pyplot as plt
import seaborn as sns

labels = ['Healthy (Z)', 'Epileptic (S)']
plt.figure(figsize=(6, 5))
sns.heatmap(total_conf_matrix, annot=True, fmt=".0f", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Aggregated Confusion Matrix")
plt.show()
# Out:
# Iteration 1/100
# Iteration 2/100
# Iteration 3/100
# Iteration 4/100
# Iteration 5/100
# Iteration 6/100
# Iteration 7/100
# Iteration 8/100
# Iteration 9/100
# Iteration 10/100
# Iteration 11/100
# Iteration 12/100
# Iteration 13/100
# Iteration 14/100
# Iteration 15/100
# Iteration 16/100
# Iteration 17/100
# Iteration 18/100
# Iteration 19/100
# Iteration 20/100
# Iteration 21/100
# Iteration 22/100
# Iteration 23/100
# Iteration 24/100
# Iteration 25/100
# Iteration 26/100
# Iteration 27/100
# Iteration 28/100
# Iteration 29/100
# Iteration 30/100
# Iteration 31/100
# Iteration 32/100
# Iteration 33/100
# Iteration 34/100
# Iteration 35/100
# Iteration 36/100
# Iteration 37/100
# Iteration 38/100
# Iteration 39/100
# Iteration 40/100
# Iteration 41/100
# Iteration 42/100
# Iteration 43/100
# Iteration 44/100
# Iteration 45/100
# Iteration 46/100
# Iteration 47/100
# Iteration 48/100
# Iteration 49/100
# Iteration 50/100
# Iteration 51/100
# Iteration 52/100
# Iteration 53/100
# Iteration 54/100
# Iteration 55/100
# Iteration 56/100
# Iteration 57/100
# Iteration 58/100
# Iteration 59/100
# Iteration 60/100
# Iteration 61/100
# Iteration 62/100
# Iteration 63/100
# Iteration 64/100
# Iteration 65/100
# Iteration 66/100
# Iteration 67/100
# Iteration 68/100
# Iteration 69/100
# Iteration 70/100
# Iteration 71/100
# Iteration 72/100
# Iteration 73/100
# Iteration 74/100
# Iteration 75/100
# Iteration 76/100
# Iteration 77/100
# Iteration 78/100
# Iteration 79/100
# Iteration 80/100
# Iteration 81/100
# Iteration 82/100
# Iteration 83/100
# Iteration 84/100
# Iteration 85/100
# Iteration 86/100
# Iteration 87/100
# Iteration 88/100
# Iteration 89/100
# Iteration 90/100
# Iteration 91/100
# Iteration 92/100
# Iteration 93/100
# Iteration 94/100
# Iteration 95/100
# Iteration 96/100
# Iteration 97/100
# Iteration 98/100
# Iteration 99/100
# Iteration 100/100
# Accuracies across 100 iterations: [0.55, 0.575, 0.475, 0.4, 0.55, 0.525, 0.45, 0.425, 0.425, 0.6, 0.45, 0.475, 0.55, 0.45, 0.525, 0.65, 0.575, 0.6, 0.475, 0.475, 0.6, 0.475, 0.45, 0.5, 0.55, 0.425, 0.525, 0.575, 0.475, 0.55, 0.55, 0.4, 0.5, 0.575, 0.45, 0.5, 0.8, 0.4, 0.425, 0.55, 0.425, 0.575, 0.35, 0.55, 0.575, 0.475, 0.45, 0.45, 0.775, 0.525, 0.525, 0.5, 0.525, 0.425, 0.4, 0.475, 0.475, 0.55, 0.45, 0.6, 0.375, 0.5, 0.575, 0.525, 0.525, 0.375, 0.425, 0.425, 0.425, 0.5, 0.275, 0.375, 0.475, 0.4, 0.4, 0.5, 0.575, 0.375, 0.825, 0.45, 0.5, 0.35, 0.4, 0.525, 0.5, 0.475, 0.5, 0.575, 0.575, 0.45, 0.525, 0.525, 0.525, 0.55, 0.525, 0.5, 0.55, 0.425, 0.425, 0.5]
# Mean Accuracy: 0.4975
# Aggregated Confusion Matrix:
#  [[ 967. 1059.]
#  [ 951. 1023.]]
